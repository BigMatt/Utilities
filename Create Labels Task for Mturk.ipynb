# %%
import sys

# %%
for i in range(1,11):
    print """
    <!-- ---- LABEL {0}--------- -->
<div class="row col-xs-12 col-md-12"><!-- Instructions -->
<div class="panel panel-primary">
<div class="panel-heading">&nbsp;</div>

<div class="panel-body">
<h1 class="panel-heading">Does this label accurately describe the following paragraph:</h1>

<p>&nbsp;</p>

<h2><strong>Label: ${{Label_{0}}}</strong></h2>

<p>&nbsp;</p>

<p>&nbsp;</p>

<h4><strong>Paragraph: </strong>${{Abstract_{0}}}</h4>
</div>
<!-- End Instructions --><!-- Content Body -->

<section>
<fieldset><label>{0}. Does this label match the paragraph?:</label>

<div class="radio"><label><input name="Correct_{0}" type="radio" value="yes" />Yes</label></div>

<div class="radio"><label><input name="Correct_{0}" type="radio" value="No" />No</label></div>
</fieldset>
</section>
</div>
<!-------END LABEL {0}------->

    
    """.format(i)
# Out:
#     <!-- ---- LABEL 1--------- -->
# <div class="row col-xs-12 col-md-12"><!-- Instructions -->
# <div class="panel panel-primary">
# <div class="panel-heading">&nbsp;</div>
#
# <div class="panel-body">
# <h1 class="panel-heading">Does this label accurately describe the following paragraph:</h1>
#
# <p>&nbsp;</p>
#
# <h2><strong>Label: ${Label_1}</strong></h2>
#
# <p>&nbsp;</p>
#
# <p>&nbsp;</p>
#
# <h4><strong>Paragraph: </strong>${Abstract_1}</h4>
# </div>
# <!-- End Instructions --><!-- Content Body -->
#
# <section>
# <fieldset><label>1. Does this label match the paragraph?:</label>
#
# <div class="radio"><label><input name="Correct_1" type="radio" value="yes" />Yes</label></div>
#
# <div class="radio"><label><input name="Correct_1" type="radio" value="No" />No</label></div>
# </fieldset>
# </section>
# </div>
# <!-------END LABEL 1------->
#
#
#
#
#     <!-- ---- LABEL 2--------- -->
# <div class="row col-xs-12 col-md-12"><!-- Instructions -->
# ...
